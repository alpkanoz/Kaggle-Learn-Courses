# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    # YOUR CODE HERE
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
q_1.solution()
# Out:
# Solution:
# ```python
#
# from tensorflow import keras
# from tensorflow.keras import layers
#
# model = keras.Sequential([
#     # Block One
#     layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
#                   input_shape=[128, 128, 3]),
#     layers.MaxPool2D(),
#
#     # Block Two
#     layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Block Three
#     layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
#     layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Head
#     layers.Flatten(),
#     layers.Dense(6, activation='relu'),
#     layers.Dropout(0.2),
#     layers.Dense(1, activation='sigmoid'),
# ])
#
# ```

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 35s 318ms/step - loss: 0.6804 - binary_accuracy: 0.5705 - val_loss: 0.6683 - val_binary_accuracy: 0.5785
# Epoch 2/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6640 - binary_accuracy: 0.5787 - val_loss: 0.6566 - val_binary_accuracy: 0.5785
# Epoch 3/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6587 - binary_accuracy: 0.5787 - val_loss: 0.6505 - val_binary_accuracy: 0.5785
# Epoch 4/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6547 - binary_accuracy: 0.6035 - val_loss: 0.6460 - val_binary_accuracy: 0.5935
# Epoch 5/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6447 - binary_accuracy: 0.6218 - val_loss: 0.6376 - val_binary_accuracy: 0.6114
# Epoch 6/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6371 - binary_accuracy: 0.6404 - val_loss: 0.6325 - val_binary_accuracy: 0.6343
# Epoch 7/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6221 - binary_accuracy: 0.6529 - val_loss: 0.6142 - val_binary_accuracy: 0.6585
# Epoch 8/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6121 - binary_accuracy: 0.6650 - val_loss: 0.5993 - val_binary_accuracy: 0.6710
# Epoch 9/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5971 - binary_accuracy: 0.6791 - val_loss: 0.5909 - val_binary_accuracy: 0.6793
# Epoch 10/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5833 - binary_accuracy: 0.6861 - val_loss: 0.5783 - val_binary_accuracy: 0.6955
# Epoch 11/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5756 - binary_accuracy: 0.6969 - val_loss: 0.5669 - val_binary_accuracy: 0.7020
# Epoch 12/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5650 - binary_accuracy: 0.7127 - val_loss: 0.5544 - val_binary_accuracy: 0.7205
# Epoch 13/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5455 - binary_accuracy: 0.7297 - val_loss: 0.5483 - val_binary_accuracy: 0.7210
# Epoch 14/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5217 - binary_accuracy: 0.7526 - val_loss: 0.5276 - val_binary_accuracy: 0.7355
# Epoch 15/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5098 - binary_accuracy: 0.7536 - val_loss: 0.5142 - val_binary_accuracy: 0.7490
# Epoch 16/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4858 - binary_accuracy: 0.7639 - val_loss: 0.5029 - val_binary_accuracy: 0.7577
# Epoch 17/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4690 - binary_accuracy: 0.7782 - val_loss: 0.4856 - val_binary_accuracy: 0.7686
# Epoch 18/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4513 - binary_accuracy: 0.7928 - val_loss: 0.4710 - val_binary_accuracy: 0.7802
# Epoch 19/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4236 - binary_accuracy: 0.8057 - val_loss: 0.4550 - val_binary_accuracy: 0.7890
# Epoch 20/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4026 - binary_accuracy: 0.8218 - val_loss: 0.4754 - val_binary_accuracy: 0.7666
# Epoch 21/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3847 - binary_accuracy: 0.8355 - val_loss: 0.4371 - val_binary_accuracy: 0.7935
# Epoch 22/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3600 - binary_accuracy: 0.8433 - val_loss: 0.4429 - val_binary_accuracy: 0.7919
# Epoch 23/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3493 - binary_accuracy: 0.8507 - val_loss: 0.4808 - val_binary_accuracy: 0.7662
# Epoch 24/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3383 - binary_accuracy: 0.8501 - val_loss: 0.4361 - val_binary_accuracy: 0.7897
# Epoch 25/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2966 - binary_accuracy: 0.8722 - val_loss: 0.4613 - val_binary_accuracy: 0.7848
# Epoch 26/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2755 - binary_accuracy: 0.8867 - val_loss: 0.4947 - val_binary_accuracy: 0.7781
# Epoch 27/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2489 - binary_accuracy: 0.9007 - val_loss: 0.4449 - val_binary_accuracy: 0.8012
# Epoch 28/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2395 - binary_accuracy: 0.9040 - val_loss: 0.4382 - val_binary_accuracy: 0.8088
# Epoch 29/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2437 - binary_accuracy: 0.8982 - val_loss: 0.4239 - val_binary_accuracy: 0.8038
# Epoch 30/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2288 - binary_accuracy: 0.9017 - val_loss: 0.4567 - val_binary_accuracy: 0.7985
# Epoch 31/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2472 - binary_accuracy: 0.8953 - val_loss: 0.4417 - val_binary_accuracy: 0.8355
# Epoch 32/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2169 - binary_accuracy: 0.9097 - val_loss: 0.4671 - val_binary_accuracy: 0.8323
# Epoch 33/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1890 - binary_accuracy: 0.9252 - val_loss: 0.5077 - val_binary_accuracy: 0.8333
# Epoch 34/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1668 - binary_accuracy: 0.9386 - val_loss: 0.5209 - val_binary_accuracy: 0.8319
# Epoch 35/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1456 - binary_accuracy: 0.9474 - val_loss: 0.4620 - val_binary_accuracy: 0.8454
# Epoch 36/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1257 - binary_accuracy: 0.9562 - val_loss: 0.5254 - val_binary_accuracy: 0.8398
# Epoch 37/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1357 - binary_accuracy: 0.9494 - val_loss: 0.5946 - val_binary_accuracy: 0.8309
# Epoch 38/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1306 - binary_accuracy: 0.9517 - val_loss: 0.6509 - val_binary_accuracy: 0.8313
# Epoch 39/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1396 - binary_accuracy: 0.9441 - val_loss: 0.6641 - val_binary_accuracy: 0.8289
# Epoch 40/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1245 - binary_accuracy: 0.9541 - val_loss: 0.7153 - val_binary_accuracy: 0.8270
# Epoch 41/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1375 - binary_accuracy: 0.9500 - val_loss: 0.4462 - val_binary_accuracy: 0.8432
# Epoch 42/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1264 - binary_accuracy: 0.9533 - val_loss: 0.6301 - val_binary_accuracy: 0.8284
# Epoch 43/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1437 - binary_accuracy: 0.9455 - val_loss: 0.7075 - val_binary_accuracy: 0.7971
# Epoch 44/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1504 - binary_accuracy: 0.9443 - val_loss: 0.5383 - val_binary_accuracy: 0.8418
# Epoch 45/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1399 - binary_accuracy: 0.9517 - val_loss: 0.5592 - val_binary_accuracy: 0.8442
# Epoch 46/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1131 - binary_accuracy: 0.9607 - val_loss: 0.5240 - val_binary_accuracy: 0.8406
# Epoch 47/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0897 - binary_accuracy: 0.9721 - val_loss: 0.5697 - val_binary_accuracy: 0.8472
# Epoch 48/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0718 - binary_accuracy: 0.9807 - val_loss: 0.5779 - val_binary_accuracy: 0.8515
# Epoch 49/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0732 - binary_accuracy: 0.9793 - val_loss: 0.5272 - val_binary_accuracy: 0.8529
# Epoch 50/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0732 - binary_accuracy: 0.9807 - val_loss: 0.5454 - val_binary_accuracy: 0.8515

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
